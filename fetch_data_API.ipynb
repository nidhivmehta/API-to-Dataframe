# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=81fe97bbc446794ea380341dbe08ded2&language=en-US&page=1')

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df.head()
# Out:
#        id                         title  \
# 0     238                 The Godfather
# 1     278      The Shawshank Redemption
# 2  315162  Puss in Boots: The Last Wish
# 3     240         The Godfather Part II
# 4     424              Schindler's List
#
#                                             overview release_date  popularity  \
# 0  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     120.671
# 1  Framed in the 1940s for the double murder of h...   1994-09-23      94.662
# 2  Puss in Boots discovers that his passion for a...   2022-12-07   10895.482
# 3  In the continuing saga of the Corleone crime f...   1974-12-20      73.612
# 4  The true story of how businessman Oskar Schind...   1993-12-15      54.840
#
#    vote_average  vote_count
# 0           8.7       17300
# 1           8.7       23089
# 2           8.6        1793
# 3           8.6       10471
# 4           8.6       13661

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=81fe97bbc446794ea380341dbe08ded2&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = df.append(temp_df,ignore_index=True)

# %%
df
# Out:
#           id                         title  \
# 0        238                 The Godfather
# 1        278      The Shawshank Redemption
# 2     315162  Puss in Boots: The Last Wish
# 3        240         The Godfather Part II
# 4        424              Schindler's List
# ...      ...                           ...
# 8555    9348                       Species
# 8556    2687   Memoirs of an Invisible Man
# 8557  396806                          Anon
# 8558  203665               Paris or Perish
# 8559   99579            Farewell, My Queen
#
#                                                overview release_date  \
# 0     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 1     Framed in the 1940s for the double murder of h...   1994-09-23
# 2     Puss in Boots discovers that his passion for a...   2022-12-07
# 3     In the continuing saga of the Corleone crime f...   1974-12-20
# 4     The true story of how businessman Oskar Schind...   1993-12-15
# ...

# %%
df.shape
# Out:
# (8560, 7)

# %%
df.to_csv('movies.csv')
